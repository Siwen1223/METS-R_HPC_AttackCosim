# %% [markdown]
# # Interactive METS-R + Simu5G V2X Attack Example
#
# This notebook is a Simu5G-backed replacement sketch for Attack 1 in `security_examples.ipynb`. Instead of reading and replaying BSMs through Kafka, it keeps METS-R as the interactive simulator, sends vehicle mobility and BSM payloads to the OMNeT++ bridge with `VeinsClient.sync_tick()`, and lets the real Simu5G Uu backend decide delivery, loss, and latency.
#
# Start the Simu5G bridge in a separate terminal before running the notebook:
#
# ```bash
# cd veins_bridge/omnetpp
# bash ./build_sim5g.sh
# bash ./run_sim5g_uu.sh
# ```
#
# The notebook can connect to an already-running METS-R interactive instance, or launch the METS-R Docker run. The results are pretty much the same as in `security_examples.ipynb`, except this one also provide the communication latency.

# %%
from pathlib import Path
import copy
import json
import math
import os
import sys
from collections import deque

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import display

if os.path.basename(os.getcwd()) == "tutorials":
    os.chdir("..")
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

from clients.METSRClient import METSRClient
from clients.VeinsClient import VeinsClient, build_mobility_records
from tutorials.v2x_veins_example import communication_records_from_result
from utils.util import read_run_config, prepare_sim_dirs, run_simulation_in_docker

print("Working directory:", os.getcwd())
# Out:
# Working directory: /home/siwen/Software/METS-R_docker/METS-R_HPC

# %% [markdown]
# ## Experiment knobs
#
# The defaults mirror the original BSM replay attack's CARLA Town 07 config and private connected vehicles. Keep `REQUIRE_SIMU5G_UU = True` when you want to guarantee that this is not falling back to the abstract bridge.

# %%
RUN_CONFIG_PATH = f"{os.getcwd()}/configs/run_cosim_CARLAT7.json"

METSR_HOST = "localhost"
METSR_PORT = 4000
VEINS_HOST = "127.0.0.1"
VEINS_PORT = 9099
METSR_TRANSFORM_COORDS = True  # Use metric x/y coordinates for Euclidean distance and Simu5G mobility.

REPLAY_SOURCE_VID = 0
REPLAY_SOURCE_RADIO_ID = 1000  # Simu5G/bridge vehicle ids must be nonzero.
EGO_VID = 1
PRIVATE_VEHICLE = True
ORIGIN_ROAD = "-20"
DESTINATION_ROAD = "-20"

# Match Attack 1 in security_examples.ipynb: 3000 ticks to record,
# then 6000 ticks for each normal/attacked run at the config step size.
RECORD_TICKS = 3000
RUN_TICKS = 6000
NORMAL_TICKS = RUN_TICKS
ATTACK_TICKS = RUN_TICKS
REPLAY_OFFSET_TICKS = 10
PAYLOAD_BYTES = 320
TABLE_ROWS = 30

TARGET_VELOCITY_MPS = 10.0
MAX_ACCELERATION_MPS2 = 2.0
KP_SPEED = 0.5
MIN_GAP_M = 5.0
SLOW_SOURCE_TARGET_SPEED_MPS = 1.0
SLOW_SOURCE_BRAKE_MPS2 = -0.5

# %%
def bridge_field(payload, key, default=None):
    if not isinstance(payload, dict):
        return default
    data = payload.get("data")
    if isinstance(data, dict) and key in data:
        return data[key]
    return payload.get(key, default)
def vehicle_id(record):
    return record.get("ID", record.get("vehicle_id", record.get("vid")))
def vehicle_has_road(record):
    return bool(record) and any(record.get(key) is not None for key in ("road", "road_id", "roadID"))

# Normalization function to convert METS-R vehicle records to a consistent format for analysis and replay.
def normalize_vehicle(record, private_veh=PRIVATE_VEHICLE, role="vehicle"):
    return {
        "ID": vehicle_id(record),
        "role": role,
        "x": record.get("x"),
        "y": record.get("y"),
        "z": record.get("z", 0.0),
        "speed": record.get("speed", record.get("speed_mps", 0.0)),
        "bearing": record.get("bearing", record.get("heading_deg", 0.0)),
        "acc": record.get("acc", record.get("acceleration_mps2")),
        "road": record.get("road", record.get("road_id")),
        "lane": record.get("lane", record.get("lane_id")),
        "state": record.get("state"),
        "v_type": record.get("v_type", record.get("vehicle_type")),
        "private_veh": bool(private_veh),
        "sensor_type": "cv2x",
        "map_name": getattr(config, "carla_map", "Town07"),
    }


def query_vehicle_state(metsr, vid, private_veh=PRIVATE_VEHICLE):
    records = metsr.query_vehicle(
        vid,
        private_veh=private_veh,
        transform_coords=METSR_TRANSFORM_COORDS,
    ).get("DATA", [])
    if records:
        record = dict(records[0])
        record["metsr_internal_vehicle_id"] = record.get("ID")
        record["ID"] = vid
        return record
    raise RuntimeError(f"Vehicle {vid} was not returned by METS-R.")


def wait_until_on_road(metsr, vid, private_veh=PRIVATE_VEHICLE, max_ticks=180):
    for _ in range(max_ticks):
        record = query_vehicle_state(metsr, vid, private_veh=private_veh)
        if (
            record
            and record.get("x") is not None
            and record.get("y") is not None
            and int(record.get("state", 1)) > 0
            and vehicle_has_road(record)
        ):
            return record
        metsr.tick()
    raise RuntimeError(f"Vehicle {vid} did not enter the road network within {max_ticks} ticks.")


def start_metsr_run(config):
    sim_dirs = prepare_sim_dirs(config)
    run_simulation_in_docker(config)
    port = METSR_PORT
    if port is None:
        port = config.ports[0] if hasattr(config, "ports") else config.metsr_port[0]
    client = METSRClient(
        host=METSR_HOST,
        port=int(port),
        sim_folder=sim_dirs[0] if sim_dirs else None
    )
    return client, sim_dirs


def stop_metsr_run(client):
    if client is None:
        return
    try:
        client.terminate()
    except Exception:
        client.close()


def spawn_ego_vehicle(metsr):
    metsr.tick(10)
    metsr.generate_trip_between_roads(EGO_VID, ORIGIN_ROAD, DESTINATION_ROAD)
    metsr.update_vehicle_sensor_type(EGO_VID, "cv2x", private_veh=PRIVATE_VEHICLE)
    return wait_until_on_road(metsr, EGO_VID)

# %%
def v2x_tick(veins, tick, vehicles, messages, phase):
    mobility = build_mobility_records(vehicles)
    # sync_tick returns a dict with bridge fields and a "communication_records" list with one record per message-vehicle pair.
    # mobility's format is a list of dicts with keys like "id", "x", "y", "speed", etc. for each vehicle, which Simu5G/bridge uses to update the mobility of its simulated vehicles.
    result = veins.sync_tick(
        tick=tick,
        vehicles=mobility,
        bsm_messages=messages,
        attacks=[],
        duration_s=0.1,
    )
    implementation = bridge_field(result, "backend_implementation")
    if implementation != "simu5g_cellular_uu":
        raise RuntimeError(
            "The bridge did not report backend_implementation=simu5g_cellular_uu. "
            f"Reported value: {implementation!r}. Start veins_bridge/omnetpp/run_sim5g_uu.sh."
        )
    rows = communication_records_from_result(result, vehicles, messages)
    for row in rows:
        row["phase"] = phase
        row["payload_x"] = row.get("tx_x")
        row["payload_y"] = row.get("tx_y")
        row["payload_speed_mps"] = row.get("tx_speed_mps")
    return result, rows


def show_records(rows, limit=TABLE_ROWS):
    def clean(value, digits=3):
        if value is None or isinstance(value, bool):
            return value
        if isinstance(value, int):
            return value
        if isinstance(value, float):
            return round(value, digits) if math.isfinite(value) else None
        if isinstance(value, dict):
            return {key: clean(item, digits) for key, item in value.items()}
        if isinstance(value, list):
            return [clean(item, digits) for item in value]
        return value

    def short_text(value, max_chars=180):
        if value is None:
            return None
        text = json.dumps(value, sort_keys=True, default=str) if isinstance(value, (dict, list)) else str(value)
        return text if len(text) <= max_chars else text[: max_chars - 3] + "..."

    latencies = [float(row["latency_ms"]) for row in rows if row.get("latency_ms") not in (None, "")]
    distances = [float(row["distance_m"]) for row in rows if row.get("distance_m") not in (None, "")]
    delivered_count = sum(1 for row in rows if row.get("delivered"))
    drop_reasons = {}
    for row in rows:
        if not row.get("delivered"):
            reason = row.get("drop_reason") or "not_delivered"
            drop_reasons[reason] = drop_reasons.get(reason, 0) + 1

    summary = {
        "rows_total": len(rows),
        "rows_shown": min(limit, len(rows)),
        "delivered": delivered_count,
        "dropped": len(rows) - delivered_count,
        "delivery_rate": None if not rows else round(delivered_count / len(rows), 3),
        "selected_by_controller": sum(1 for row in rows if row.get("controller_selected")),
        "latency_ms": None
        if not latencies
        else {
            "mean": clean(sum(latencies) / len(latencies)),
            "min": clean(min(latencies)),
            "max": clean(max(latencies)),
        },
        "distance_m": None
        if not distances
        else {
            "mean": clean(sum(distances) / len(distances)),
            "min": clean(min(distances)),
            "max": clean(max(distances)),
        },
        "drop_reasons": drop_reasons,
    }

    messages = []
    for row in rows[:limit]:
        item = {
            "phase": row.get("phase"),
            "tick": row.get("tick"),
            "message": {
                "id": row.get("message_id"),
                "name": row.get("message_name"),
                "standard": row.get("message_standard"),
                "count": row.get("message_count"),
                "attacked": row.get("attacked"),
                "content": short_text(row.get("message_content")),
            },
            "link": {
                "origin_vehicle_id": row.get("origin_vehicle_id"),
                "target_vehicle_id": row.get("target_vehicle_id"),
                "distance_m": clean(row.get("distance_m")),
                "delivered": row.get("delivered"),
                "latency_ms": clean(row.get("latency_ms")),
                "drop_reason": row.get("drop_reason"),
            },
            "origin_location": {
                "x_m": clean(row.get("origin_x")),
                "y_m": clean(row.get("origin_y")),
            },
            "target_location": {
                "x_m": clean(row.get("target_x")),
                "y_m": clean(row.get("target_y")),
            },
            "payload_vehicle_state": {
                "x_m": clean(row.get("payload_x")),
                "y_m": clean(row.get("payload_y")),
                "speed_mps": clean(row.get("payload_speed_mps")),
            },
        }
        if row.get("controller_selected") is not None or row.get("command_reason") is not None:
            item["controller"] = {
                "selected": row.get("controller_selected"),
                "command_acc_mps2": clean(row.get("command_acc_mps2")),
                "reason": row.get("command_reason"),
            }
        messages.append(item)

    print(json.dumps({"summary": summary, "messages": messages}, indent=2, default=str))


def trace_rows(trace, phase):
    rows = []
    for segment_tick, row in enumerate(trace):
        item = dict(row)
        item["phase"] = phase
        item["segment_tick"] = segment_tick
        rows.append(item)
    return rows

def numeric_trace_values(trace, key):
    values = []
    for row in trace:
        value = row.get(key)
        values.append(math.nan if value in (None, "") else float(value))
    return values

# %% [markdown]
# ## Connect to METS-R and the Simu5G bridge

# %%
config = read_run_config(str(RUN_CONFIG_PATH))
metsr, sim_dirs = start_metsr_run(config)

veins = VeinsClient(
    host=VEINS_HOST,
    port=VEINS_PORT,
    connect_timeout=30,
    request_timeout=60,
)
veins.connect()

print(f"connected_to_metsr host={metsr.host} port={metsr.port}")
print(f"connected_to_veins_bridge host={veins.host} port={veins.port}")
print(json.dumps(veins.bridge_info, indent=2))
# Out:
# Connection established!
# connected_to_metsr host=localhost port=4000
# connected_to_veins_bridge host=127.0.0.1 port=9099
# {
#   "backend_implementation": "simu5g_cellular_uu",
#   "backend_note": "True Simu5G Uu backend: BSM payloads are delivered through Simu5G UE/gNB modules.",
#   "bridge_backend": "sim5g_cellular_uu",
#   "bridge_model": "simu5g_nr_uu",
#   "network_model": "simu5g_nr_uu",
#   "protocol": "metsr-veins-jsonl",
#   "radio_access": "5g_nr_uu",
#   "request_id": 1,
#   "status": "ok",
#   "type": "hello_result",
#   "version": 1
# }

# %% [markdown]
# ## Phase 1: record BSM payloads from the live simulator
#
# This phase queries METS-R vehicle states each tick, sends truthful BSMs to Simu5G, and keeps source-to-ego payloads for later replay.

# %%
metsr.generate_trip_between_roads(REPLAY_SOURCE_VID, ORIGIN_ROAD, DESTINATION_ROAD)
metsr.update_vehicle_sensor_type(REPLAY_SOURCE_VID, "cv2x", private_veh=PRIVATE_VEHICLE)
source_state = wait_until_on_road(metsr, REPLAY_SOURCE_VID)
replay_buffer = deque(maxlen=RECORD_TICKS)
record_rows = []

for local_tick in range(RECORD_TICKS):
    source_state = query_vehicle_state(metsr, REPLAY_SOURCE_VID)
    if float(source_state.get("speed", 0.0) or 0.0) > SLOW_SOURCE_TARGET_SPEED_MPS:
        metsr.control_vehicle(REPLAY_SOURCE_VID, SLOW_SOURCE_BRAKE_MPS2, private_veh=PRIVATE_VEHICLE)

    metsr.tick()
    source_state = query_vehicle_state(metsr, REPLAY_SOURCE_VID)

    source = normalize_vehicle(source_state, role="replay_source")
    source["ID"] = REPLAY_SOURCE_RADIO_ID
    source["metsr_vehicle_id"] = REPLAY_SOURCE_VID
    recorder = dict(source)
    recorder.update(
        {
            "ID": EGO_VID,
            "role": "recording_sink",
            "x": float(source.get("x", 0.0)) + 10.0,
            "speed": 0.0,
        }
    )
    participants = [source, recorder]

    source_id = vehicle_id(source)
    recorder_id = vehicle_id(recorder)
    messages = [
        {
            "message_id": f"record:{local_tick}:{source_id}>{recorder_id}:1",
            "tick": local_tick,
            "vehicle_id": source_id,
            "sender_id": source_id,
            "receiver_id": recorder_id,
            "target_vehicle_id": recorder_id,
            "message_name": "BasicSafetyMessage",
            "message_standard": "SAE J2735-aligned",
            "message_count": (local_tick * 16 + 1) % 128,
            "payload_bytes": PAYLOAD_BYTES,
            "tx_time_s": local_tick * float(getattr(config, "sim_step_size", 0.1)),
            "radio_mode": "cv2x",
            "content": (
                f"record BSM tick={local_tick} metsr_veh={REPLAY_SOURCE_VID} radio_veh={source_id} "
                f"pos=({float(source.get('x', 0.0)):.2f},{float(source.get('y', 0.0)):.2f},{float(source.get('z', 0.0)):.2f}) "
                f"speed={float(source.get('speed', 0.0) or 0.0):.2f}mps "
                f"heading={float(source.get('bearing', 0.0) or 0.0):.1f}deg"
            ),
            "map_name": getattr(config, "carla_map", "Town07"),
            "sender_role": source.get("role"),
            "receiver_role": recorder.get("role"),
            "x": source.get("x"),
            "y": source.get("y"),
            "z": source.get("z", 0.0),
            "speed_mps": source.get("speed", 0.0),
            "heading_deg": source.get("bearing", 0.0),
            "truth_x": source.get("x"),
            "truth_y": source.get("y"),
            "truth_speed_mps": source.get("speed", 0.0),
            "truth_heading_deg": source.get("bearing", 0.0),
            "attacked": False,
            "attack_id": "",
            "attack_type": "",
        }
    ]

    _, rows = v2x_tick(veins, local_tick, participants, messages, phase="record")
    replay_buffer.append(copy.deepcopy(messages[0]))
    record_rows.extend(rows)

print(f"recorded_payloads={len(replay_buffer)} communication_rows={len(record_rows)}")
show_records(record_rows, limit=10)
# Out:
# recorded_payloads=3000 communication_rows=3000
# {
#   "summary": {
#     "rows_total": 3000,
#     "rows_shown": 10,
#     "delivered": 2996,
#     "dropped": 4,
#     "delivery_rate": 0.999,
#     "selected_by_controller": 0,
#     "latency_ms": {
#       "mean": 22.895,
#       "min": 19.0,
#       "max": 43.0
#     },
#     "distance_m": {
#       "mean": 10.0,
#       "min": 10.0,
#       "max": 10.0
#     },
#     "drop_reasons": {
#       "simu5g_receive_timeout": 4
#     }
#   },
#   "messages": [
#     {
#       "phase": "record",
#       "tick": 0,
#       "message": {
#         "id": "record:0:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 1,
#         "attacked": false,
#         "content": "record BSM tick=0 metsr_veh=0 radio_veh=1000 pos=(72.37,7.82,0.07) speed=0.00mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "target_location": {
#         "x_m": 82.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.37,
#         "y_m": 7.82,
#         "speed_mps": 0.0
#       }
#     },
#     {
#       "phase": "record",
#       "tick": 1,
#       "message": {
#         "id": "record:1:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 17,
#         "attacked": false,
#         "content": "record BSM tick=1 metsr_veh=0 radio_veh=1000 pos=(72.37,7.82,0.07) speed=0.00mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "target_location": {
#         "x_m": 82.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.37,
#         "y_m": 7.82,
#         "speed_mps": 0.0
#       }
#     },
#     {
#       "phase": "record",
#       "tick": 2,
#       "message": {
#         "id": "record:2:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 33,
#         "attacked": false,
#         "content": "record BSM tick=2 metsr_veh=0 radio_veh=1000 pos=(72.37,7.82,0.07) speed=0.00mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "target_location": {
#         "x_m": 82.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.37,
#         "y_m": 7.82,
#         "speed_mps": 0.0
#       }
#     },
#     {
#       "phase": "record",
#       "tick": 3,
#       "message": {
#         "id": "record:3:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 49,
#         "attacked": false,
#         "content": "record BSM tick=3 metsr_veh=0 radio_veh=1000 pos=(72.37,7.82,0.07) speed=0.00mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "target_location": {
#         "x_m": 82.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.37,
#         "y_m": 7.82,
#         "speed_mps": 0.0
#       }
#     },
#     {
#       "phase": "record",
#       "tick": 4,
#       "message": {
#         "id": "record:4:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 65,
#         "attacked": false,
#         "content": "record BSM tick=4 metsr_veh=0 radio_veh=1000 pos=(72.37,7.82,0.07) speed=0.00mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "target_location": {
#         "x_m": 82.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.37,
#         "y_m": 7.82,
#         "speed_mps": 0.0
#       }
#     },
#     {
#       "phase": "record",
#       "tick": 5,
#       "message": {
#         "id": "record:5:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 81,
#         "attacked": false,
#         "content": "record BSM tick=5 metsr_veh=0 radio_veh=1000 pos=(72.37,7.82,0.07) speed=0.00mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "target_location": {
#         "x_m": 82.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.37,
#         "y_m": 7.82,
#         "speed_mps": 0.0
#       }
#     },
#     {
#       "phase": "record",
#       "tick": 6,
#       "message": {
#         "id": "record:6:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 97,
#         "attacked": false,
#         "content": "record BSM tick=6 metsr_veh=0 radio_veh=1000 pos=(72.37,7.82,0.07) speed=0.00mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "target_location": {
#         "x_m": 82.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.37,
#         "y_m": 7.82,
#         "speed_mps": 0.0
#       }
#     },
#     {
#       "phase": "record",
#       "tick": 7,
#       "message": {
#         "id": "record:7:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 113,
#         "attacked": false,
#         "content": "record BSM tick=7 metsr_veh=0 radio_veh=1000 pos=(72.37,7.82,0.07) speed=0.00mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "target_location": {
#         "x_m": 82.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.37,
#         "y_m": 7.82,
#         "speed_mps": 0.0
#       }
#     },
#     {
#       "phase": "record",
#       "tick": 8,
#       "message": {
#         "id": "record:8:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 1,
#         "attacked": false,
#         "content": "record BSM tick=8 metsr_veh=0 radio_veh=1000 pos=(72.38,7.83,0.07) speed=0.28mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 31.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.376,
#         "y_m": 7.832
#       },
#       "target_location": {
#         "x_m": 82.376,
#         "y_m": 7.832
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.376,
#         "y_m": 7.832,
#         "speed_mps": 0.28
#       }
#     },
#     {
#       "phase": "record",
#       "tick": 9,
#       "message": {
#         "id": "record:9:1000>1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 17,
#         "attacked": false,
#         "content": "record BSM tick=9 metsr_veh=0 radio_veh=1000 pos=(72.40,7.87,0.07) speed=0.56mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 10.0,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.396,
#         "y_m": 7.87
#       },
#       "target_location": {
#         "x_m": 82.396,
#         "y_m": 7.87
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.396,
#         "y_m": 7.87,
#         "speed_mps": 0.56
#       }
#     }
#   ]
# }

# %% [markdown]
# ## Phase 2: replay stale BSMs through Simu5G and control the ego vehicle
#
# This starts a fresh METS-R run, generates only the ego vehicle, then injects historical replay-source BSMs through Simu5G. The ego controller reacts only to replay messages that Simu5G reports as delivered.

# %%
if not replay_buffer:
    raise RuntimeError("Run the record phase before the attack phase.")

metsr.reset()
ego_state = spawn_ego_vehicle(metsr)

attack_rows = []
control_trace = []
replay_payloads = list(replay_buffer)

for local_tick in range(ATTACK_TICKS):
    tick = RECORD_TICKS + local_tick
    metsr.tick()
    ego_state = query_vehicle_state(metsr, EGO_VID)
    ego = normalize_vehicle(ego_state, role="ego")
    participants = [ego]
    messages = []
    injected = 0

    replay_index = local_tick + REPLAY_OFFSET_TICKS
    if replay_index < len(replay_payloads):
        stale = replay_payloads[replay_index]
        replay_x = stale.get("x")
        replay_y = stale.get("y")
        replay_z = stale.get("z", 0.0)
        replay_speed = stale.get("speed_mps", stale.get("speed", 0.0))
        replay_heading = stale.get("heading_deg", stale.get("heading", 0.0))

        replay_sender = {
            "ID": REPLAY_SOURCE_RADIO_ID,
            "role": "replayed_source",
            "x": replay_x,
            "y": replay_y,
            "z": replay_z,
            "speed": replay_speed,
            "bearing": replay_heading,
            "private_veh": bool(stale.get("private_veh", PRIVATE_VEHICLE)),
            "sensor_type": "cv2x",
            "map_name": stale.get("map_name", getattr(config, "carla_map", "Town07")),
        }
        replay_bsm = copy.deepcopy(stale)
        original_id = replay_bsm.get("message_id", "recorded")
        replay_bsm.update(
            {
                "message_id": f"replay:{tick}:{original_id}:1",
                "tick": tick,
                "vehicle_id": REPLAY_SOURCE_RADIO_ID,
                "sender_id": REPLAY_SOURCE_RADIO_ID,
                "receiver_id": vehicle_id(ego),
                "target_vehicle_id": vehicle_id(ego),
                "message_count": (tick * 16 + 1) % 128,
                "tx_time_s": tick * float(getattr(config, "sim_step_size", 0.1)),
                "x": replay_x,
                "y": replay_y,
                "z": replay_z,
                "speed_mps": replay_speed,
                "speed": replay_speed,
                "heading_deg": replay_heading,
                "heading": replay_heading,
                "attacked": True,
                "attack_id": "simu5g_bsm_replay",
                "attack_type": "bsm_replay"
            }
        )
        participants.append(replay_sender)
        messages.append(replay_bsm)
        injected = 1

    _, rows = v2x_tick(veins, tick, participants, messages, phase="attack")

    ego_x = float(ego.get("x", 0.0))
    ego_y = float(ego.get("y", 0.0))
    ego_speed = float(ego.get("speed", 0.0) or 0.0)
    front_candidates = []
    for row in rows:
        if not row.get("delivered") or row.get("target_vehicle_id") != EGO_VID:
            continue
        if row.get("payload_x") is None or row.get("payload_y") is None:
            continue
        dx = float(row["payload_x"]) - ego_x
        dy = float(row["payload_y"]) - ego_y
        distance_m = math.hypot(dx, dy)
        front_speed = float(row.get("payload_speed_mps") or 0.0)
        front_candidates.append((distance_m, front_speed, row))

    if front_candidates:
        front_distance, front_speed, chosen = min(front_candidates, key=lambda item: item[0])
        relative_speed = ego_speed - front_speed
        if front_distance < MIN_GAP_M:
            command_acc = -MAX_ACCELERATION_MPS2
            command_reason = "replay_front_inside_min_gap"
        elif front_distance < 2 * MIN_GAP_M and relative_speed > 0:
            command_acc = -min(MAX_ACCELERATION_MPS2, relative_speed ** 2 / (2 * max(front_distance - MIN_GAP_M, 0.1)))
            command_reason = "replay_front_closing"
        else:
            command_acc = KP_SPEED * (TARGET_VELOCITY_MPS - ego_speed)
            command_reason = "replay_delivered_but_not_braking"
    else:
        command_acc = KP_SPEED * (TARGET_VELOCITY_MPS - ego_speed)
        chosen = None
        front_distance = None
        front_speed = None
        command_reason = "no_delivered_replay_fallback_speed_control"
    command_acc = max(-MAX_ACCELERATION_MPS2, min(MAX_ACCELERATION_MPS2, command_acc))
    observed_acc = ego_state.get("acc", command_acc)
    if vehicle_has_road(ego_state):
        metsr.control_vehicle(EGO_VID, command_acc, private_veh=PRIVATE_VEHICLE)

    chosen_message_id = None if chosen is None else chosen.get("message_id")
    for row in rows:
        row["command_acc_mps2"] = command_acc
        row["ego_acc_mps2"] = observed_acc
        row["controller_selected"] = row.get("message_id") == chosen_message_id
        row["ego_speed_mps"] = ego.get("speed")
        row["command_reason"] = command_reason
        row["selected_distance_m"] = front_distance
    attack_rows.extend(rows)
    control_trace.append(
        {
            "tick": tick,
            "ego_speed_mps": ego.get("speed"),
            "ego_acc_mps2": observed_acc,
            "command_acc_mps2": command_acc,
            "selected_message_id": chosen_message_id,
            "selected_attack_type": None if chosen is None else chosen.get("attack_type"),
            "selected_distance_m": front_distance,
            "selected_front_speed_mps": front_speed,
            "front_candidate_count": len(front_candidates),
            "command_reason": command_reason,
            "delivered_messages_to_ego": sum(1 for row in rows if row.get("delivered") and row.get("target_vehicle_id") == EGO_VID),
            "injected_bsm_messages": injected,
        }
    )

print(f"attack_rows={len(attack_rows)}")
show_records(attack_rows, limit=TABLE_ROWS)
# Out:
# attack_rows=2990
# {
#   "summary": {
#     "rows_total": 2990,
#     "rows_shown": 30,
#     "delivered": 2983,
#     "dropped": 7,
#     "delivery_rate": 0.998,
#     "selected_by_controller": 2983,
#     "latency_ms": {
#       "mean": 26.257,
#       "min": 19.0,
#       "max": 49.0
#     },
#     "distance_m": {
#       "mean": 4.943,
#       "min": 0.126,
#       "max": 5.373
#     },
#     "drop_reasons": {
#       "simu5g_receive_timeout": 7
#     }
#   },
#   "messages": [
#     {
#       "phase": "attack",
#       "tick": 3000,
#       "message": {
#         "id": "replay:3000:record:10:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 1,
#         "attacked": true,
#         "content": "record BSM tick=10 metsr_veh=0 radio_veh=1000 pos=(72.43,7.93,0.07) speed=0.84mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 0.126,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.428,
#         "y_m": 7.932
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.428,
#         "y_m": 7.932,
#         "speed_mps": 0.84
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3001,
#       "message": {
#         "id": "replay:3001:record:11:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 17,
#         "attacked": true,
#         "content": "record BSM tick=11 metsr_veh=0 radio_veh=1000 pos=(72.47,8.02,0.07) speed=1.12mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 0.224,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.473,
#         "y_m": 8.019
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.473,
#         "y_m": 8.019,
#         "speed_mps": 1.12
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3002,
#       "message": {
#         "id": "replay:3002:record:12:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 33,
#         "attacked": true,
#         "content": "record BSM tick=12 metsr_veh=0 radio_veh=1000 pos=(72.52,8.12,0.08) speed=1.07mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 0.334,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.523,
#         "y_m": 8.116
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.523,
#         "y_m": 8.116,
#         "speed_mps": 1.07
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3003,
#       "message": {
#         "id": "replay:3003:record:13:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 49,
#         "attacked": true,
#         "content": "record BSM tick=13 metsr_veh=0 radio_veh=1000 pos=(72.57,8.21,0.08) speed=1.02mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 0.438,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.571,
#         "y_m": 8.209
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.571,
#         "y_m": 8.209,
#         "speed_mps": 1.02
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3004,
#       "message": {
#         "id": "replay:3004:record:14:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 65,
#         "attacked": true,
#         "content": "record BSM tick=14 metsr_veh=0 radio_veh=1000 pos=(72.62,8.30,0.08) speed=0.97mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 0.538,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.617,
#         "y_m": 8.297
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.617,
#         "y_m": 8.297,
#         "speed_mps": 0.97
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3005,
#       "message": {
#         "id": "replay:3005:record:15:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 81,
#         "attacked": true,
#         "content": "record BSM tick=15 metsr_veh=0 radio_veh=1000 pos=(72.67,8.40,0.08) speed=1.25mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 0.649,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.668,
#         "y_m": 8.396
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.668,
#         "y_m": 8.396,
#         "speed_mps": 1.25
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3006,
#       "message": {
#         "id": "replay:3006:record:16:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 97,
#         "attacked": true,
#         "content": "record BSM tick=16 metsr_veh=0 radio_veh=1000 pos=(72.72,8.50,0.09) speed=1.20mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 0.771,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.724,
#         "y_m": 8.505
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.724,
#         "y_m": 8.505,
#         "speed_mps": 1.2
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3007,
#       "message": {
#         "id": "replay:3007:record:17:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 113,
#         "attacked": true,
#         "content": "record BSM tick=17 metsr_veh=0 radio_veh=1000 pos=(72.78,8.61,0.09) speed=1.15mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 0.889,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.778,
#         "y_m": 8.609
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.778,
#         "y_m": 8.609,
#         "speed_mps": 1.15
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3008,
#       "message": {
#         "id": "replay:3008:record:18:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 1,
#         "attacked": true,
#         "content": "record BSM tick=18 metsr_veh=0 radio_veh=1000 pos=(72.83,8.71,0.09) speed=1.10mps heading=27.6deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 1.001,
#         "delivered": true,
#         "latency_ms": 31.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.83,
#         "y_m": 8.709
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.83,
#         "y_m": 8.709,
#         "speed_mps": 1.1
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3009,
#       "message": {
#         "id": "replay:3009:record:19:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 17,
#         "attacked": true,
#         "content": "record BSM tick=19 metsr_veh=0 radio_veh=1000 pos=(72.88,8.80,0.09) speed=1.05mps heading=27.6deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 1.109,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.88,
#         "y_m": 8.804
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.88,
#         "y_m": 8.804,
#         "speed_mps": 1.05
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3010,
#       "message": {
#         "id": "replay:3010:record:20:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 33,
#         "attacked": true,
#         "content": "record BSM tick=20 metsr_veh=0 radio_veh=1000 pos=(72.93,8.89,0.09) speed=1.00mps heading=27.6deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 1.211,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.927,
#         "y_m": 8.895
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.927,
#         "y_m": 8.895,
#         "speed_mps": 1.0
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3011,
#       "message": {
#         "id": "replay:3011:record:21:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 49,
#         "attacked": true,
#         "content": "record BSM tick=21 metsr_veh=0 radio_veh=1000 pos=(72.98,9.00,0.10) speed=1.28mps heading=27.6deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 1.325,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 72.98,
#         "y_m": 8.996
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 72.98,
#         "y_m": 8.996,
#         "speed_mps": 1.28
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3012,
#       "message": {
#         "id": "replay:3012:record:22:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 65,
#         "attacked": true,
#         "content": "record BSM tick=22 metsr_veh=0 radio_veh=1000 pos=(73.04,9.11,0.10) speed=1.23mps heading=27.6deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 1.451,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.038,
#         "y_m": 9.107
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.038,
#         "y_m": 9.107,
#         "speed_mps": 1.23
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3013,
#       "message": {
#         "id": "replay:3013:record:23:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 81,
#         "attacked": true,
#         "content": "record BSM tick=23 metsr_veh=0 radio_veh=1000 pos=(73.09,9.21,0.10) speed=1.18mps heading=27.6deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 1.571,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.094,
#         "y_m": 9.214
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.094,
#         "y_m": 9.214,
#         "speed_mps": 1.18
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3014,
#       "message": {
#         "id": "replay:3014:record:24:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 97,
#         "attacked": true,
#         "content": "record BSM tick=24 metsr_veh=0 radio_veh=1000 pos=(73.15,9.32,0.10) speed=1.13mps heading=27.6deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 1.687,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.148,
#         "y_m": 9.316
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.148,
#         "y_m": 9.316,
#         "speed_mps": 1.13
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3015,
#       "message": {
#         "id": "replay:3015:record:25:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 113,
#         "attacked": true,
#         "content": "record BSM tick=25 metsr_veh=0 radio_veh=1000 pos=(73.20,9.41,0.11) speed=1.08mps heading=27.6deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 1.797,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.199,
#         "y_m": 9.414
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.199,
#         "y_m": 9.414,
#         "speed_mps": 1.08
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3016,
#       "message": {
#         "id": "replay:3016:record:26:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 1,
#         "attacked": true,
#         "content": "record BSM tick=26 metsr_veh=0 radio_veh=1000 pos=(73.25,9.51,0.11) speed=1.03mps heading=27.6deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 1.903,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.248,
#         "y_m": 9.507
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.248,
#         "y_m": 9.507,
#         "speed_mps": 1.03
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3017,
#       "message": {
#         "id": "replay:3017:record:27:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 17,
#         "attacked": true,
#         "content": "record BSM tick=27 metsr_veh=0 radio_veh=1000 pos=(73.29,9.60,0.11) speed=0.98mps heading=27.1deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 2.003,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.294,
#         "y_m": 9.597
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.294,
#         "y_m": 9.597,
#         "speed_mps": 0.98
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3018,
#       "message": {
#         "id": "replay:3018:record:28:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 33,
#         "attacked": true,
#         "content": "record BSM tick=28 metsr_veh=0 radio_veh=1000 pos=(73.34,9.70,0.12) speed=1.25mps heading=27.1deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 2.114,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.345,
#         "y_m": 9.696
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.345,
#         "y_m": 9.696,
#         "speed_mps": 1.249
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3019,
#       "message": {
#         "id": "replay:3019:record:29:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 49,
#         "attacked": true,
#         "content": "record BSM tick=29 metsr_veh=0 radio_veh=1000 pos=(73.40,9.80,0.12) speed=1.20mps heading=27.1deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 2.237,
#         "delivered": true,
#         "latency_ms": 31.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.4,
#         "y_m": 9.805
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.4,
#         "y_m": 9.805,
#         "speed_mps": 1.199
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3020,
#       "message": {
#         "id": "replay:3020:record:30:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 65,
#         "attacked": true,
#         "content": "record BSM tick=30 metsr_veh=0 radio_veh=1000 pos=(73.45,9.91,0.12) speed=1.15mps heading=27.1deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 2.354,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.454,
#         "y_m": 9.909
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.454,
#         "y_m": 9.909,
#         "speed_mps": 1.149
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3021,
#       "message": {
#         "id": "replay:3021:record:31:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 81,
#         "attacked": true,
#         "content": "record BSM tick=31 metsr_veh=0 radio_veh=1000 pos=(73.51,10.01,0.13) speed=1.10mps heading=27.1deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 2.467,
#         "delivered": true,
#         "latency_ms": 19.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.505,
#         "y_m": 10.01
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.505,
#         "y_m": 10.01,
#         "speed_mps": 1.099
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3022,
#       "message": {
#         "id": "replay:3022:record:32:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 97,
#         "attacked": true,
#         "content": "record BSM tick=32 metsr_veh=0 radio_veh=1000 pos=(73.55,10.11,0.13) speed=1.05mps heading=27.1deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 2.574,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.554,
#         "y_m": 10.105
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.554,
#         "y_m": 10.105,
#         "speed_mps": 1.049
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3023,
#       "message": {
#         "id": "replay:3023:record:33:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 113,
#         "attacked": true,
#         "content": "record BSM tick=33 metsr_veh=0 radio_veh=1000 pos=(73.60,10.20,0.13) speed=1.00mps heading=27.1deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 2.677,
#         "delivered": true,
#         "latency_ms": 31.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.601,
#         "y_m": 10.196
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.601,
#         "y_m": 10.196,
#         "speed_mps": 0.999
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3024,
#       "message": {
#         "id": "replay:3024:record:34:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 1,
#         "attacked": true,
#         "content": "record BSM tick=34 metsr_veh=0 radio_veh=1000 pos=(73.65,10.30,0.14) speed=1.27mps heading=27.1deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 2.79,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.652,
#         "y_m": 10.297
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.652,
#         "y_m": 10.297,
#         "speed_mps": 1.269
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3025,
#       "message": {
#         "id": "replay:3025:record:35:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 17,
#         "attacked": true,
#         "content": "record BSM tick=35 metsr_veh=0 radio_veh=1000 pos=(73.71,10.41,0.14) speed=1.22mps heading=27.1deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 2.915,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.709,
#         "y_m": 10.408
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.709,
#         "y_m": 10.408,
#         "speed_mps": 1.219
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3026,
#       "message": {
#         "id": "replay:3026:record:36:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 33,
#         "attacked": true,
#         "content": "record BSM tick=36 metsr_veh=0 radio_veh=1000 pos=(73.76,10.51,0.14) speed=1.17mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 3.034,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.764,
#         "y_m": 10.514
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.764,
#         "y_m": 10.514,
#         "speed_mps": 1.169
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3027,
#       "message": {
#         "id": "replay:3027:record:37:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 49,
#         "attacked": true,
#         "content": "record BSM tick=37 metsr_veh=0 radio_veh=1000 pos=(73.82,10.62,0.14) speed=1.12mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 3.148,
#         "delivered": true,
#         "latency_ms": 31.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.816,
#         "y_m": 10.616
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.816,
#         "y_m": 10.616,
#         "speed_mps": 1.119
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3028,
#       "message": {
#         "id": "replay:3028:record:38:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 65,
#         "attacked": true,
#         "content": "record BSM tick=38 metsr_veh=0 radio_veh=1000 pos=(73.87,10.71,0.15) speed=1.07mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 3.258,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.867,
#         "y_m": 10.713
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.867,
#         "y_m": 10.713,
#         "speed_mps": 1.069
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     },
#     {
#       "phase": "attack",
#       "tick": 3029,
#       "message": {
#         "id": "replay:3029:record:39:1000>1:1:1",
#         "name": "BasicSafetyMessage",
#         "standard": null,
#         "count": 81,
#         "attacked": true,
#         "content": "record BSM tick=39 metsr_veh=0 radio_veh=1000 pos=(73.91,10.81,0.15) speed=1.02mps heading=27.3deg"
#       },
#       "link": {
#         "origin_vehicle_id": 1000,
#         "target_vehicle_id": 1,
#         "distance_m": 3.362,
#         "delivered": true,
#         "latency_ms": 25.0,
#         "drop_reason": ""
#       },
#       "origin_location": {
#         "x_m": 73.915,
#         "y_m": 10.805
#       },
#       "target_location": {
#         "x_m": 72.37,
#         "y_m": 7.82
#       },
#       "payload_vehicle_state": {
#         "x_m": 73.915,
#         "y_m": 10.805,
#         "speed_mps": 1.019
#       },
#       "controller": {
#         "selected": true,
#         "command_acc_mps2": -2.0,
#         "reason": "replay_front_inside_min_gap"
#       }
#     }
#   ]
# }

# %% [markdown]
# ## Phase 3: normal ego control
#
# This starts another fresh METS-R run and applies the original Attack 1 normal controller: the ego vehicle tries to reach the target speed and does not react to front-vehicle BSM candidates.

# %%
metsr.reset()
ego_state = spawn_ego_vehicle(metsr)

normal_rows = []
normal_trace = []

for local_tick in range(NORMAL_TICKS):
    tick = RECORD_TICKS + ATTACK_TICKS + local_tick
    metsr.tick(1, wait_forever=True)
    ego_state = query_vehicle_state(metsr, EGO_VID)
    ego = normalize_vehicle(ego_state, role="ego")

    _, rows = v2x_tick(veins, tick, [ego], [], phase="normal")
    ego_speed = float(ego.get("speed", 0.0) or 0.0)
    command_acc = KP_SPEED * (TARGET_VELOCITY_MPS - ego_speed)
    command_acc = max(-MAX_ACCELERATION_MPS2, min(MAX_ACCELERATION_MPS2, command_acc))
    observed_acc = ego_state.get("acc", command_acc)
    if vehicle_has_road(ego_state):
        metsr.control_vehicle(EGO_VID, command_acc, private_veh=PRIVATE_VEHICLE)

    for row in rows:
        row["command_acc_mps2"] = command_acc
        row["ego_acc_mps2"] = observed_acc
        row["ego_speed_mps"] = ego.get("speed")
    normal_rows.extend(rows)
    normal_trace.append(
        {
            "tick": tick,
            "ego_speed_mps": ego.get("speed"),
            "ego_acc_mps2": observed_acc,
            "command_acc_mps2": command_acc,
            "selected_message_id": None,
            "selected_attack_type": None,
            "selected_distance_m": None,
            "selected_front_speed_mps": None,
            "front_candidate_count": 0,
            "command_reason": "normal_speed_control",
            "delivered_messages_to_ego": 0,
        }
    )

print(f"normal_rows={len(normal_rows)}")
show_records(normal_rows, limit=TABLE_ROWS)
# Out:
# normal_rows=0
# {
#   "summary": {
#     "rows_total": 0,
#     "rows_shown": 0,
#     "delivered": 0,
#     "dropped": 0,
#     "delivery_rate": null,
#     "selected_by_controller": 0,
#     "latency_ms": null,
#     "distance_m": null,
#     "drop_reasons": {}
#   },
#   "messages": []
# }

# %% [markdown]
# ## Summarize and visualize the run

# %%
all_rows = record_rows + attack_rows + normal_rows
delivered = [row for row in all_rows if row.get("delivered")]
attack_delivered = [row for row in attack_rows if row.get("delivered") and row.get("attacked")]
latencies = [float(row["latency_ms"]) for row in delivered if row.get("latency_ms") not in (None, "")]

normal_speed = numeric_trace_values(normal_trace, "ego_speed_mps")
attacked_speed = numeric_trace_values(control_trace, "ego_speed_mps")
normal_acc = numeric_trace_values(normal_trace, "ego_acc_mps2")
attacked_acc = numeric_trace_values(control_trace, "ego_acc_mps2")

min_len = min(len(normal_speed), len(attacked_speed))
if np is not None and min_len:
    speed_delta = np.abs(
        np.asarray(attacked_speed[:min_len], dtype=float)
        - np.asarray(normal_speed[:min_len], dtype=float)
    )
else:
    speed_delta = [abs(attacked_speed[i] - normal_speed[i]) for i in range(min_len)]

recovery_tick = None
recovery_window = 100
recovery_threshold = 0.5
for index in range(RECORD_TICKS, max(RECORD_TICKS, min_len - recovery_window)):
    window = speed_delta[index : index + recovery_window]
    if len(window) and max(window) <= recovery_threshold:
        recovery_tick = index
        break

sim_step = float(getattr(config, "sim_step_size", 0.1))
bsm_replay_result = {
    "recorded_bsm_messages": int(sum(1 for row in record_rows if row.get("origin_vehicle_id") == REPLAY_SOURCE_RADIO_ID)),
    "ticks_with_replay_data": len(replay_buffer),
    "injected_bsm_messages": int(sum(row.get("injected_bsm_messages", 0) for row in control_trace)),
    "replay_duration_seconds": RECORD_TICKS * sim_step,
    "recovery_start_seconds": None if recovery_tick is None else recovery_tick * sim_step,
    "normal_speed": normal_speed,
    "attacked_speed": attacked_speed,
    "normal_acc": normal_acc,
    "attacked_acc": attacked_acc,
}
attack_reason_counts = {}
for row in control_trace:
    reason = row.get("command_reason", "unknown")
    attack_reason_counts[reason] = attack_reason_counts.get(reason, 0) + 1

summary = {
    "backend_implementation": bridge_field(veins.bridge_info, "backend_implementation", "see sync_tick rows"),
    "record_rows": len(record_rows),
    "normal_rows": len(normal_rows),
    "attack_rows": len(attack_rows),
    "delivered_rows": len(delivered),
    "delivered_replay_rows": len(attack_delivered),
    "mean_latency_ms": None if not latencies else sum(latencies) / len(latencies),
    "max_latency_ms": None if not latencies else max(latencies),
    "recorded_bsm_messages": bsm_replay_result["recorded_bsm_messages"],
    "ticks_with_replay_data": bsm_replay_result["ticks_with_replay_data"],
    "injected_bsm_messages": bsm_replay_result["injected_bsm_messages"],
    "replay_duration_seconds": bsm_replay_result["replay_duration_seconds"],
    "recovery_start_seconds": bsm_replay_result["recovery_start_seconds"],
    "attack_ticks_with_delivered_replay": int(sum(1 for row in control_trace if row.get("front_candidate_count", 0) > 0)),
    "attack_ticks_braking_from_replay": int(sum(1 for row in control_trace if str(row.get("command_reason", "")).startswith("replay_front"))),
    "attack_command_reasons": attack_reason_counts,
}
print(json.dumps(summary, indent=2))

comparison_trace = trace_rows(control_trace, "attack") + trace_rows(normal_trace, "normal")
trace_preview = [
    {
        "phase": row.get("phase"),
        "segment_tick": row.get("segment_tick"),
        "tick": row.get("tick"),
        "ego_speed_mps": row.get("ego_speed_mps"),
        "ego_acc_mps2": row.get("ego_acc_mps2"),
        "selected_message_id": row.get("selected_message_id"),
        "selected_distance_m": row.get("selected_distance_m"),
        "command_reason": row.get("command_reason"),
        "delivered_messages_to_ego": row.get("delivered_messages_to_ego"),
    }
    for row in comparison_trace[: 2 * TABLE_ROWS]
]
print(
    json.dumps(
        {
            "trace_rows_total": len(comparison_trace),
            "trace_rows_shown": len(trace_preview),
            "trace_preview": trace_preview,
        },
        indent=2,
        default=str,
    )
)

if plt is not None:
    if np is not None:
        x_seconds = np.arange(len(normal_speed)) * sim_step
    else:
        x_seconds = [index * sim_step for index in range(len(normal_speed))]

    fig, axes = plt.subplots(2, 2, figsize=(11, 6), sharex=True)
    axes[0, 0].plot(x_seconds, normal_speed, lw=0.6)
    axes[0, 1].plot(x_seconds, attacked_speed, lw=0.6, color="tab:red")
    axes[1, 0].plot(x_seconds, normal_acc, lw=0.6)
    axes[1, 1].plot(x_seconds, attacked_acc, lw=0.6, color="tab:red")

    axes[0, 0].set_title("Normal speed")
    axes[0, 1].set_title("Attacked speed")
    axes[1, 0].set_title("Normal acceleration")
    axes[1, 1].set_title("Attacked acceleration")
    axes[0, 0].set_ylabel("Speed (m/s)")
    axes[1, 0].set_ylabel("Acceleration (m/s^2)")
    axes[1, 0].set_xlabel("Second")
    axes[1, 1].set_xlabel("Second")

    for axis in axes.ravel():
        axis.axvline(bsm_replay_result["replay_duration_seconds"], color="0.4", ls="--", lw=0.8)
        if bsm_replay_result["recovery_start_seconds"] is not None:
            axis.axvline(bsm_replay_result["recovery_start_seconds"], color="tab:green", ls=":", lw=1.0)

    plt.suptitle("BSM replay attack: normal vs replayed historical stream")
    fig.tight_layout()
    plt.show()
else:
    print("matplotlib is not installed; skipped speed/acceleration plots.")

{key: bsm_replay_result[key] for key in ("recorded_bsm_messages", "ticks_with_replay_data", "injected_bsm_messages", "replay_duration_seconds", "recovery_start_seconds")} if bsm_replay_result else None
# Out:
# {
#   "backend_implementation": "simu5g_cellular_uu",
#   "record_rows": 3000,
#   "normal_rows": 0,
#   "attack_rows": 2990,
#   "delivered_rows": 5979,
#   "delivered_replay_rows": 2983,
#   "mean_latency_ms": 24.572503763168942,
#   "max_latency_ms": 49.000000000006594,
#   "recorded_bsm_messages": 3000,
#   "ticks_with_replay_data": 3000,
#   "injected_bsm_messages": 2990,
#   "replay_duration_seconds": 300.0,
#   "recovery_start_seconds": null,
#   "attack_ticks_with_delivered_replay": 2983,
#   "attack_ticks_braking_from_replay": 2325,
#   "attack_command_reasons": {
#     "replay_front_inside_min_gap": 1296,
#     "replay_delivered_but_not_braking": 658,
#     "replay_front_closing": 1029,
#     "no_delivered_replay_fallback_speed_control": 3017
#   }
# }
# {
#   "trace_rows_total": 12000,
#   "trace_rows_shown": 60,
#   "trace_preview": [
#     {
#       "phase": "attack",
#       "segment_tick": 0,
#       "tick": 3000,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3000:record:10:1000>1:1:1",
#       "selected_distance_m": 0.12598608674045755,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 1,
#       "tick": 3001,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3001:record:11:1000>1:1:1",
#       "selected_distance_m": 0.22397505773315898,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 2,
#       "tick": 3002,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3002:record:12:1000>1:1:1",
#       "selected_distance_m": 0.33346231933663484,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 3,
#       "tick": 3003,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3003:record:13:1000>1:1:1",
#       "selected_distance_m": 0.43794958079079954,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 4,
#       "tick": 3004,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3004:record:14:1000>1:1:1",
#       "selected_distance_m": 0.5374368420956174,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 5,
#       "tick": 3005,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3005:record:15:1000>1:1:1",
#       "selected_distance_m": 0.6484222634847467,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 6,
#       "tick": 3006,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3006:record:16:1000>1:1:1",
#       "selected_distance_m": 0.7709058449581825,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 7,
#       "tick": 3007,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3007:record:17:1000>1:1:1",
#       "selected_distance_m": 0.8883894262823138,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 8,
#       "tick": 3008,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3008:record:18:1000>1:1:1",
#       "selected_distance_m": 1.0008727730356906,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 9,
#       "tick": 3009,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3009:record:19:1000>1:1:1",
#       "selected_distance_m": 1.1083553127407293,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 10,
#       "tick": 3010,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3010:record:20:1000>1:1:1",
#       "selected_distance_m": 1.2108380729082946,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 11,
#       "tick": 3011,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3011:record:21:1000>1:1:1",
#       "selected_distance_m": 1.3248097955798421,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 12,
#       "tick": 3012,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3012:record:22:1000>1:1:1",
#       "selected_distance_m": 1.4502704854362234,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 13,
#       "tick": 3013,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3013:record:23:1000>1:1:1",
#       "selected_distance_m": 1.5707313086086514,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 14,
#       "tick": 3014,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3014:record:24:1000>1:1:1",
#       "selected_distance_m": 1.686192231437322,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 15,
#       "tick": 3015,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3015:record:25:1000>1:1:1",
#       "selected_distance_m": 1.7966532307687841,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 16,
#       "tick": 3016,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3016:record:26:1000>1:1:1",
#       "selected_distance_m": 1.9021142901585977,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 17,
#       "tick": 3017,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3017:record:27:1000>1:1:1",
#       "selected_distance_m": 2.0025743624853667,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 18,
#       "tick": 3018,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3018:record:28:1000>1:1:1",
#       "selected_distance_m": 2.114009867457896,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 19,
#       "tick": 3019,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3019:record:29:1000>1:1:1",
#       "selected_distance_m": 2.2364218350900225,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 20,
#       "tick": 3020,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3020:record:30:1000>1:1:1",
#       "selected_distance_m": 2.3538341175378226,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 21,
#       "tick": 3021,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3021:record:31:1000>1:1:1",
#       "selected_distance_m": 2.4662466579083127,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 22,
#       "tick": 3022,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3022:record:32:1000>1:1:1",
#       "selected_distance_m": 2.573659412477618,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 23,
#       "tick": 3023,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3023:record:33:1000>1:1:1",
#       "selected_distance_m": 2.6760723471081644,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 24,
#       "tick": 3024,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3024:record:34:1000>1:1:1",
#       "selected_distance_m": 2.7894616522426774,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 25,
#       "tick": 3025,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3025:record:35:1000>1:1:1",
#       "selected_distance_m": 2.913827346230091,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 26,
#       "tick": 3026,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3026:record:36:1000>1:1:1",
#       "selected_distance_m": 3.033194359053847,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 27,
#       "tick": 3027,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3027:record:37:1000>1:1:1",
#       "selected_distance_m": 3.1475613953743893,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 28,
#       "tick": 3028,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3028:record:38:1000>1:1:1",
#       "selected_distance_m": 3.2569284316070597,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 29,
#       "tick": 3029,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3029:record:39:1000>1:1:1",
#       "selected_distance_m": 3.3612954677436346,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 30,
#       "tick": 3030,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3030:record:40:1000>1:1:1",
#       "selected_distance_m": 3.460662503777354,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 31,
#       "tick": 3031,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3031:record:41:1000>1:1:1",
#       "selected_distance_m": 3.5715276500883593,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 32,
#       "tick": 3032,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3032:record:42:1000>1:1:1",
#       "selected_distance_m": 3.693890906682398,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 33,
#       "tick": 3033,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3033:record:43:1000>1:1:1",
#       "selected_distance_m": 3.8112541631711125,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 34,
#       "tick": 3034,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3034:record:44:1000>1:1:1",
#       "selected_distance_m": 3.923617135803162,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 35,
#       "tick": 3035,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3035:record:45:1000>1:1:1",
#       "selected_distance_m": 4.030979341260822,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 36,
#       "tick": 3036,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3036:record:46:1000>1:1:1",
#       "selected_distance_m": 4.133341646371011,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 37,
#       "tick": 3037,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3037:record:47:1000>1:1:1",
#       "selected_distance_m": 4.2466802540983055,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 38,
#       "tick": 3038,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3038:record:48:1000>1:1:1",
#       "selected_distance_m": 4.370995175748386,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 39,
#       "tick": 3039,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3039:record:49:1000>1:1:1",
#       "selected_distance_m": 4.490310192961834,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 40,
#       "tick": 3040,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3040:record:50:1000>1:1:1",
#       "selected_distance_m": 4.604625295231906,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 41,
#       "tick": 3041,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3041:record:51:1000>1:1:1",
#       "selected_distance_m": 4.713940473635554,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 42,
#       "tick": 3042,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3042:record:52:1000>1:1:1",
#       "selected_distance_m": 4.818255720552973,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 43,
#       "tick": 3043,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3043:record:53:1000>1:1:1",
#       "selected_distance_m": 4.917570661874244,
#       "command_reason": "replay_front_inside_min_gap",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 44,
#       "tick": 3044,
#       "ego_speed_mps": 0.0,
#       "ego_acc_mps2": 0.0,
#       "selected_message_id": "replay:3044:record:54:1000>1:1:1",
#       "selected_distance_m": 5.027408935523613,
#       "command_reason": "replay_delivered_but_not_braking",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 45,
#       "tick": 3045,
#       "ego_speed_mps": 0.20000000298023224,
#       "ego_acc_mps2": 2.0,
#       "selected_message_id": "replay:3045:record:55:1000>1:1:1",
#       "selected_distance_m": 5.137770846837418,
#       "command_reason": "replay_delivered_but_not_braking",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 46,
#       "tick": 3046,
#       "ego_speed_mps": 0.4000000059604645,
#       "ego_acc_mps2": 2.0,
#       "selected_message_id": "replay:3046:record:56:1000>1:1:1",
#       "selected_distance_m": 5.22313288075427,
#       "command_reason": "replay_delivered_but_not_braking",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 47,
#       "tick": 3047,
#       "ego_speed_mps": 0.6000000089406967,
#       "ego_acc_mps2": 2.0,
#       "selected_message_id": "replay:3047:record:57:1000>1:1:1",
#       "selected_distance_m": 5.2834950238969265,
#       "command_reason": "replay_delivered_but_not_braking",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 48,
#       "tick": 3048,
#       "ego_speed_mps": 0.800000011920929,
#       "ego_acc_mps2": 2.0,
#       "selected_message_id": "replay:3048:record:58:1000>1:1:1",
#       "selected_distance_m": 5.318857265670748,
#       "command_reason": "replay_delivered_but_not_braking",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 49,
#       "tick": 3049,
#       "ego_speed_mps": 1.0000000149011612,
#       "ego_acc_mps2": 2.0,
#       "selected_message_id": "replay:3049:record:59:1000>1:1:1",
#       "selected_distance_m": 5.329219597609096,
#       "command_reason": "replay_front_closing",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 50,
#       "tick": 3050,
#       "ego_speed_mps": 0.9999306805878186,
#       "ego_acc_mps2": -0.0006933431230934507,
#       "selected_message_id": "replay:3050:record:60:1000>1:1:1",
#       "selected_distance_m": 5.340109084184315,
#       "command_reason": "replay_delivered_but_not_braking",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 51,
#       "tick": 3051,
#       "ego_speed_mps": 1.1999306835680508,
#       "ego_acc_mps2": 2.0,
#       "selected_message_id": "replay:3051:record:61:1000>1:1:1",
#       "selected_distance_m": 5.351525737417642,
#       "command_reason": "replay_front_closing",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 52,
#       "tick": 3052,
#       "ego_speed_mps": 1.1999140253365865,
#       "ego_acc_mps2": -0.00016658231215920257,
#       "selected_message_id": "replay:3052:record:62:1000>1:1:1",
#       "selected_distance_m": 5.347918639119703,
#       "command_reason": "replay_front_closing",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 53,
#       "tick": 3053,
#       "ego_speed_mps": 1.1993826811144996,
#       "ego_acc_mps2": -0.005313442141692129,
#       "selected_message_id": "replay:3053:record:63:1000>1:1:1",
#       "selected_distance_m": 5.339327531449639,
#       "command_reason": "replay_front_closing",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 54,
#       "tick": 3054,
#       "ego_speed_mps": 1.1975908492516587,
#       "ego_acc_mps2": -0.01791831836140545,
#       "selected_message_id": "replay:3054:record:64:1000>1:1:1",
#       "selected_distance_m": 5.325855775200072,
#       "command_reason": "replay_front_closing",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 55,
#       "tick": 3055,
#       "ego_speed_mps": 1.1937369047175073,
#       "ego_acc_mps2": -0.03853944476723231,
#       "selected_message_id": "replay:3055:record:65:1000>1:1:1",
#       "selected_distance_m": 5.307669310147545,
#       "command_reason": "replay_front_closing",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 56,
#       "tick": 3056,
#       "ego_speed_mps": 1.186932079829452,
#       "ego_acc_mps2": -0.06804824786655476,
#       "selected_message_id": "replay:3056:record:66:1000>1:1:1",
#       "selected_distance_m": 5.30112129625053,
#       "command_reason": "replay_delivered_but_not_braking",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 57,
#       "tick": 3057,
#       "ego_speed_mps": 1.3869320828096843,
#       "ego_acc_mps2": 2.0,
#       "selected_message_id": "replay:3057:record:67:1000>1:1:1",
#       "selected_distance_m": 5.296019536442979,
#       "command_reason": "replay_front_closing",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 58,
#       "tick": 3058,
#       "ego_speed_mps": 1.3817170263799465,
#       "ego_acc_mps2": -0.05215056352027454,
#       "selected_message_id": "replay:3058:record:68:1000>1:1:1",
#       "selected_distance_m": 5.276183013381831,
#       "command_reason": "replay_front_closing",
#       "delivered_messages_to_ego": 1
#     },
#     {
#       "phase": "attack",
#       "segment_tick": 59,
#       "tick": 3059,
#       "ego_speed_mps": 1.3729149850701066,
#       "ego_acc_mps2": -0.08802041178679337,
#       "selected_message_id": "replay:3059:record:69:1000>1:1:1",
#       "selected_distance_m": 5.252051323951022,
#       "command_reason": "replay_front_closing",
#       "delivered_messages_to_ego": 1
#     }
#   ]
# }
# {'recorded_bsm_messages': 3000,
#  'ticks_with_replay_data': 3000,
#  'injected_bsm_messages': 2990,
#  'replay_duration_seconds': 300.0,
#  'recovery_start_seconds': None}

# %% [markdown]
# ## Cleanup
#
# Closing the clients leaves an externally-started METS-R simulator running. If this notebook launched METS-R and `TERMINATE_METSR_WHEN_DONE` is true, it sends `CTRL_end`.

# %%
try:
    veins.close()
except NameError:
    pass

try:
    stop_metsr_run(metsr)
except NameError:
    pass
